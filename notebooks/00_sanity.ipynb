# %% [markdown]
# # SPECTRA Sanity Check
#
# Quick test of the fusion pipeline.

# %%
import sys
import os
sys.path.insert(0, '../src')

from spectra_core.pipeline import run_pipeline
from IPython.display import Image, display

# Run fusion on sample data (update paths as needed)
efc_path, metrics, summary = run_pipeline(
    red_path="../data/S2_B04.tif",
    nir_path="../data/S2_B08.tif",
    sar_c_path="../data/S1_C.tif",
    output_dir="../outputs/"
)

print(f"Summary: {summary}")
print(f"Metrics: {metrics}")

# %%
# Display the EFC image
display(Image("../outputs/efc.png"))
